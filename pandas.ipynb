# %%
import pandas as pd
data = [10, 20, 30, 40, 12, 23, 34, 45, 57]
s = pd.Series(data)

print(s)
print(s[0:4])
print(s[0:8:2])
print(s[2:7])
print(s[-7:-3])
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    12
# 5    23
# 6    34
# 7    45
# 8    57
# dtype: int64
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64
# 0    10
# 2    30
# 4    12
# 6    34
# dtype: int64
# 2    30
# 3    40
# 4    12
# 5    23
# 6    34
# dtype: int64
# 2    30
# 3    40
# 4    12
# 5    23
# dtype: int64
